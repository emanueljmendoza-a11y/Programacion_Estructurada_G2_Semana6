# %%
vector = []
vector.append(8)
vector.append(9)
vector.append(11)
print (vector)
print (vector[0])
print (vector[1])
print (vector[2])

#imprime
print (vector[-1])
print (vector[-2])
print (vector[-3])
# Out:
# [8, 9, 11]
# 8
# 9
# 11
# 11
# 9
# 8

# %%
#Arreglo de  diferetnes tipos de datos
vector2 = [3, 4.56 , "Luis"]
print (vector2)
# Out:
# [3, 4.56, 'Luis']

# %%
#Insertar un elemento en la posicion 1
vector2.insert(1, "Managua")
print (vector2)
# Out:
# [3, 'Managua', 4.56, 'Luis']

# %%
#recorrer el vector 
for item in vector2:
    print (item)
# Out:
# 3
# Managua
# 4.56
# Luis

# %%
#Recorrer el vector 
for index in range (4):
    print (vector2[index])
# Out:
# 3
# Managua
# 4.56
# Luis
